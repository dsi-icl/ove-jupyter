# %%
# %load_ext autoreload
# %autoreload 2
# %load_ext ove
# %ove_config --space DOCluster --rows 16 --cols 4 --env ".env" -rm True

# %%
import pandas as pd

from matplotlib import pyplot as plt

# %%
# %%tee 1
# df = pd.DataFrame({"a": [32, 45, 90, 80], "b": [91, 67, 2, 38]})
# df.head()
# Out:
#     a   b
# 0  32  91
# 1  45  67
# 2  90   2
# 3  80  38
#         <iframe
#             width="100%"
#             height="400px"
#             src="http://gdo-apps.dsi.ic.ac.uk:9080/app/html/control.html?oveSectionId=126"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# %%tee 2 -r 1 -c 2
# plt.plot([0, 1, 2, 3, 4], [76, 80, 67, 92, 95])
# plt.show()
# Out:
# 146.169.10.250 - - [19/May/2023 21:46:29] "GET /cell-1-0-0.html HTTP/1.1" 200 -
#         <iframe
#             width="100%"
#             height="400px"
#             src="http://gdo-apps.dsi.ic.ac.uk:9080/app/images/control.html?oveSectionId=127"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# %%tee 3 -h 1080 -w 3840 -x 0 -y 1080
# df = pd.DataFrame({"a": [0, 1, 2, 3], "b": [4, 5, 6, 7]})
# df.head()
# Out:
#    a  b
# 0  0  4
# 1  1  5
# 2  2  6
# 3  3  7
#         <iframe
#             width="100%"
#             height="400px"
#             src="http://gdo-apps.dsi.ic.ac.uk:9080/app/html/control.html?oveSectionId=128"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# %%tee 4 -f 1 3 -t 3 5
# plt.plot([0, 1, 2, 3, 4], [5, 9, 2, 10, 4])
# plt.show()
# Out:
#         <iframe
#             width="100%"
#             height="400px"
#             src="http://gdo-apps.dsi.ic.ac.uk:9080/app/images/control.html?oveSectionId=129"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
