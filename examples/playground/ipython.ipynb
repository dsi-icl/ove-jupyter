# %%
# %load_ext autoreload
# %autoreload 2
# %load_ext ove_jupyter
# %ove_config --observatory dev --env ".env" -rm True -m development
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# The ove_jupyter extension is already loaded. To reload it, use:
#   %reload_ext ove_jupyter
# DELETE: http://192.168.78.1:9081/sections?space=dev

# %%
import pandas as pd

from matplotlib import pyplot as plt
from IPython.display import Audio, Code, GeoJSON, IFrame, Image, JSON, Latex, Markdown, Math, Video, YouTubeVideo

# %%
# %%tee 1
# df = pd.DataFrame({"a": [32, 45, 90, 80], "b": [91, 67, 2, 38]})
# df.head()
# Out:
# POST: http://192.168.78.1:9081/section - {'app': {'states': {'load': {'url': 'http://127.0.0.1/ove-jupyter/static/cell-1-0.html'}}, 'url': 'http://192.168.78.1:9081/app/html'}, 'h': 1080.0, 'w': 1920.0, 'x': 0.0, 'y': 0.0, 'space': 'dev'}
# Injecting: http://192.168.78.1:9081/app/html/control.html?oveSectionId=0
#     a   b
# 0  32  91
# 1  45  67
# 2  90   2
# 3  80  38

# %%
# %%tee 2 -r 1 -c 2
# plt.plot([0, 1, 2, 3, 4], [76, 80, 67, 92, 95])
# plt.show()
# Out:
# POST: http://192.168.78.1:9081/section - {'app': {'states': {'load': {'url': 'http://127.0.0.1/ove-jupyter/static/cell-2-0.png'}}, 'url': 'http://192.168.78.1:9081/app/images'}, 'h': 1080.0, 'w': 1920.0, 'x': 1920.0, 'y': 0.0, 'space': 'dev'}
# Injecting: http://192.168.78.1:9081/app/images/control.html?oveSectionId=1

# %%
# %%tee 3 -h 1/4 -w 1/8 -x 0 -y 1/4
# df = pd.DataFrame({"a": [0, 1, 2, 3], "b": [4, 5, 6, 7]})
# df.head()
# Out:
# POST: http://192.168.78.1:9081/section - {'app': {'states': {'load': {'url': 'http://127.0.0.1/ove-jupyter/static/cell-3-0.html'}}, 'url': 'http://192.168.78.1:9081/app/html'}, 'h': 1080.0, 'w': 3840.0, 'x': 0.0, 'y': 1080.0, 'space': 'dev'}
# Injecting: http://192.168.78.1:9081/app/html/control.html?oveSectionId=2
#    a  b
# 0  0  4
# 1  1  5
# 2  2  6
# 3  3  7

# %%
# %%tee 4 -f 1 3 -t 3 5
# plt.plot([0, 1, 2, 3, 4], [5, 9, 2, 10, 4])
# plt.show()
# Out:
# POST: http://192.168.78.1:9081/section - {'app': {'states': {'load': {'url': 'http://127.0.0.1/ove-jupyter/static/cell-4-0.png'}}, 'url': 'http://192.168.78.1:9081/app/images'}, 'h': 2160.0, 'w': 3840.0, 'x': 0.0, 'y': 2160.0, 'space': 'dev'}
# Injecting: http://192.168.78.1:9081/app/images/control.html?oveSectionId=3

# %%
# %%tee 9
# Math(r'F(k) = \int_{-\infty}^{\infty} f(x) e^{2\pi i k} dx')
# Out:
# POST: http://192.168.78.1:9081/section - {'app': {'states': {'load': {'url': 'http://127.0.0.1/ove-jupyter/static/cell-9-0.html'}}, 'url': 'http://192.168.78.1:9081/app/html'}, 'h': 1080.0, 'w': 1920.0, 'x': 3840.0, 'y': 0.0, 'space': 'dev'}
# Injecting: http://192.168.78.1:9081/app/html/control.html?oveSectionId=4
# $\displaystyle F(k) = \int_{-\infty}^{\infty} f(x) e^{2\pi i k} dx$

# %%
# %%tee 10
# Latex("$$c = \\sqrt{a^2 + b^2}$$")
# Out:
# POST: http://192.168.78.1:9081/section - {'app': {'states': {'load': {'url': 'http://127.0.0.1/ove-jupyter/static/cell-10-0.html'}}, 'url': 'http://192.168.78.1:9081/app/html'}, 'h': 1080.0, 'w': 1920.0, 'x': 3840.0, 'y': 1080.0, 'space': 'dev'}
# Injecting: http://192.168.78.1:9081/app/html/control.html?oveSectionId=5
# $$c = \sqrt{a^2 + b^2}$$

# %%
# %%tee 11
# with open("./README.md", "r") as f:
#     md = "\n".join(f.readlines())
# Markdown(md)
# Out:
# POST: http://192.168.78.1:9081/section - {'app': {'states': {'load': {'url': 'http://127.0.0.1/ove-jupyter/static/cell-11-0.html'}}, 'url': 'http://192.168.78.1:9081/app/html'}, 'h': 1080.0, 'w': 1920.0, 'x': 3840.0, 'y': 2160.0, 'space': 'dev'}
# Injecting: http://192.168.78.1:9081/app/html/control.html?oveSectionId=6
# # ove-jupyter playground

# %%
# %%tee 12
# JSON({"hello": "world"})
# Out:
# POST: http://192.168.78.1:9081/section - {'app': {'states': {'load': {'url': 'http://127.0.0.1/ove-jupyter/static/cell-12-0.html'}}, 'url': 'http://192.168.78.1:9081/app/html'}, 'h': 1080.0, 'w': 1920.0, 'x': 3840.0, 'y': 3240.0, 'space': 'dev'}
# Injecting: http://192.168.78.1:9081/app/html/control.html?oveSectionId=7

# %%
# %%tee 13
# GeoJSON(data={
#     "type": "Feature",
#     "geometry": {
#         "type": "Point",
#         "coordinates": [-81.327, 296.038]
#     }
# },
# url_template="https://tile.openstreetmap.org/{z}/{x}/{y}.png",
# layer_options={
#     "minZoom" : 0,
#     "maxZoom" : 18,
# })
# Out:
# POST: http://192.168.78.1:9081/section - {'app': {'states': {'load': {'url': 'http://127.0.0.1/ove-jupyter/static/cell-13-0.json'}}, 'url': 'http://192.168.78.1:9081/app/maps'}, 'h': 1080.0, 'w': 1920.0, 'x': 5760.0, 'y': 0.0, 'space': 'dev'}
# Injecting: http://192.168.78.1:9081/app/maps/control.html?oveSectionId=8

# %%
# %%tee 14
# Video("https://archive.org/download/Sita_Sings_the_Blues/Sita_Sings_the_Blues_small.mp4")
# Out:
# POST: http://192.168.78.1:9081/section - {'app': {'states': {'load': {'url': 'https://archive.org/download/Sita_Sings_the_Blues/Sita_Sings_the_Blues_small.mp4'}}, 'url': 'http://192.168.78.1:9081/app/videos'}, 'h': 1080.0, 'w': 1920.0, 'x': 5760.0, 'y': 1080.0, 'space': 'dev'}
# Injecting: http://192.168.78.1:9081/app/videos/control.html?oveSectionId=9
# <video src="https://archive.org/download/Sita_Sings_the_Blues/Sita_Sings_the_Blues_small.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%tee 15
# YouTubeVideo("XY3NP4JHXZ4")
# Out:
# POST: http://192.168.78.1:9081/section - {'app': {'states': {'load': {'url': 'https://www.youtube.com/embed/XY3NP4JHXZ4'}}, 'url': 'http://192.168.78.1:9081/app/videos'}, 'h': 1080.0, 'w': 1920.0, 'x': 5760.0, 'y': 2160.0, 'space': 'dev'}
# Injecting: http://192.168.78.1:9081/app/videos/control.html?oveSectionId=10

# %%
# %%tee 16
# Audio(url="https://www.w3schools.com/html/horse.ogg")
# Out:
# POST: http://192.168.78.1:9081/section - {'app': {'states': {'load': {'url': 'https://www.w3schools.com/html/horse.ogg'}}, 'url': 'http://192.168.78.1:9081/app/audio'}, 'h': 1080.0, 'w': 1920.0, 'x': 5760.0, 'y': 3240.0, 'space': 'dev'}
# Injecting: http://192.168.78.1:9081/app/audio/control.html?oveSectionId=11
#                 <audio  controls="controls" >
#                     <source src="https://www.w3schools.com/html/horse.ogg" type="audio/ogg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# %%tee 17
# Video(filename="./data/sample.mp4")
# Out:
# POST: http://192.168.78.1:9081/section - {'app': {'states': {'load': {'url': 'http://127.0.0.1/ove-jupyter/static/cell-17-0.mp4'}}, 'url': 'http://192.168.78.1:9081/app/videos'}, 'h': 1080.0, 'w': 1920.0, 'x': 7680.0, 'y': 0.0, 'space': 'dev'}
# Injecting: http://192.168.78.1:9081/app/videos/control.html?oveSectionId=12
# <video src="./data/sample.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%tee 18
# IFrame(src="https://ove.readthedocs.io/en/stable/README.html", width="100%", height="100%")
# Out:
# POST: http://192.168.78.1:9081/section - {'app': {'states': {'load': {'url': 'http://127.0.0.1/ove-jupyter/static/cell-18-0.html'}}, 'url': 'http://192.168.78.1:9081/app/html'}, 'h': 1080.0, 'w': 1920.0, 'x': 7680.0, 'y': 1080.0, 'space': 'dev'}
# Injecting: http://192.168.78.1:9081/app/html/control.html?oveSectionId=13
#         <iframe
#             width="100%"
#             height="100%"
#             src="https://ove.readthedocs.io/en/stable/README.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# %%tee 19
# Image(filename="./data/sample.jpeg")
# Out:
# POST: http://192.168.78.1:9081/section - {'app': {'states': {'load': {'url': 'http://127.0.0.1/ove-jupyter/static/cell-19-0.jpg'}}, 'url': 'http://192.168.78.1:9081/app/images'}, 'h': 1080.0, 'w': 1920.0, 'x': 7680.0, 'y': 2160.0, 'space': 'dev'}
# Injecting: http://192.168.78.1:9081/app/images/control.html?oveSectionId=14

# %%
# %%tee 20
# Image(filename="./data/sample.png")
# Out:
# POST: http://192.168.78.1:9081/section - {'app': {'states': {'load': {'url': 'http://127.0.0.1/ove-jupyter/static/cell-20-0.png'}}, 'url': 'http://192.168.78.1:9081/app/images'}, 'h': 1080.0, 'w': 1920.0, 'x': 7680.0, 'y': 3240.0, 'space': 'dev'}
# Injecting: http://192.168.78.1:9081/app/images/control.html?oveSectionId=15

# %%
# %%tee 21 -h 1/8 1/8 -w 1/32 1/32 -x 5/16 11/32 -y 0 1/8
# display(Image(filename="./data/sample.png"))
# display(Image(filename="./data/sample.jpeg"))
# Out:
# POST: http://192.168.78.1:9081/section - {'app': {'states': {'load': {'url': 'http://127.0.0.1/ove-jupyter/static/cell-21-0.png'}}, 'url': 'http://192.168.78.1:9081/app/images'}, 'h': 540.0, 'w': 960.0, 'x': 9600.0, 'y': 0.0, 'space': 'dev'}
# POST: http://192.168.78.1:9081/section - {'app': {'states': {'load': {'url': 'http://127.0.0.1/ove-jupyter/static/cell-21-1.jpg'}}, 'url': 'http://192.168.78.1:9081/app/images'}, 'h': 540.0, 'w': 960.0, 'x': 10560.0, 'y': 540.0, 'space': 'dev'}
# Injecting: http://192.168.78.1:9081/app/images/control.html?oveSectionId=16
# Injecting: http://192.168.78.1:9081/app/images/control.html?oveSectionId=17

# %%
# %%tee 22 -r 2 3 -c 6 6
# display(Image(filename="./data/sample.png"))
# display(Image(filename="./data/sample.jpeg"))
# Out:
# POST: http://192.168.78.1:9081/section - {'app': {'states': {'load': {'url': 'http://127.0.0.1/ove-jupyter/static/cell-22-0.png'}}, 'url': 'http://192.168.78.1:9081/app/images'}, 'h': 1080.0, 'w': 1920.0, 'x': 9600.0, 'y': 1080.0, 'space': 'dev'}
# POST: http://192.168.78.1:9081/section - {'app': {'states': {'load': {'url': 'http://127.0.0.1/ove-jupyter/static/cell-22-1.jpg'}}, 'url': 'http://192.168.78.1:9081/app/images'}, 'h': 1080.0, 'w': 1920.0, 'x': 9600.0, 'y': 2160.0, 'space': 'dev'}
# Injecting: http://192.168.78.1:9081/app/images/control.html?oveSectionId=18
# Injecting: http://192.168.78.1:9081/app/images/control.html?oveSectionId=19

# %%
# %%tee 23 -r 4 -c 6 --split width
# display(Image(filename="./data/sample.png"))
# display(Image(filename="./data/sample.jpeg"))
# Out:
# POST: http://192.168.78.1:9081/section - {'app': {'states': {'load': {'url': 'http://127.0.0.1/ove-jupyter/static/cell-23-0.png'}}, 'url': 'http://192.168.78.1:9081/app/images'}, 'h': 1080.0, 'w': 960.0, 'x': 9600.0, 'y': 3240.0, 'space': 'dev'}
# POST: http://192.168.78.1:9081/section - {'app': {'states': {'load': {'url': 'http://127.0.0.1/ove-jupyter/static/cell-23-1.jpg'}}, 'url': 'http://192.168.78.1:9081/app/images'}, 'h': 1080.0, 'w': 960.0, 'x': 10560.0, 'y': 3240.0, 'space': 'dev'}
# Injecting: http://192.168.78.1:9081/app/images/control.html?oveSectionId=20
# Injecting: http://192.168.78.1:9081/app/images/control.html?oveSectionId=21
